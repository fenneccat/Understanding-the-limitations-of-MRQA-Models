# %%
import json
import spacy
import re

from tqdm import tqdm_notebook
import pandas as pd 

from collections import Counter

import matplotlib.pyplot as plt

from numpy.random import rand

from random import sample

# %%
import seaborn as sns

# %%
nlp = spacy.load('en')

# %%
f = open('all_wrong.txt','rt')
all_wrong = f.readlines()
f.close()

# %%
f = open('bert_wrong.txt','rt')
bert_wrong = f.readlines()
f.close()

# %%
f = open('doc_wrong.txt','rt')
doc_wrong = f.readlines()
f.close()

# %%
def removen(file):
    return [line.rstrip('\n') for line in file]

# %%
all_wrong = removen(all_wrong)
bert_wrong = removen(bert_wrong)
doc_wrong = removen(doc_wrong)

# %%
all_wrong = set(all_wrong)
bert_wrong = set(bert_wrong)
doc_wrong = set(doc_wrong)

# %%
rc_wrong = bert_wrong | doc_wrong

# %%
both_wrong = bert_wrong & doc_wrong

# %%
wrong_docqa = doc_wrong

# %%
wrong_bert = bert_wrong

# %%
len(bert_wrong), len(doc_wrong)
# Out:
# (2945, 2959)

# %%
len(rc_wrong), len(both_wrong)
# Out:
# (4010, 1894)

# %%
with open("trivia-qa/wikipedia-dev.json", "r") as f:
    dev = json.load(f)

# %%
with open("trivia-qa/wikipedia-train.json", "r") as f:
    train = json.load(f)

# %%
with open("trivia-qa/verified-wikipedia-dev.json", "r") as f:
    veri_dev = json.load(f)

# %%
dev = dev['Data']

# %%
#dev = veri_dev

# %%
f = open("trivia-qa/bert-large-qa_ensemble_form-dev.csv", "r")
bert = pd.read_csv(f)

# %%
f = open("trivia-qa/docqa_dev_paragraph-output.csv", "r")
docqa = pd.read_csv(f)

# %%
docqa
# Out:
#                                      doc_id  n_answers  para_end  para_start  \
# 0                 Sasquatch! Music Festival          0      1599         800
# 1         List of dialling codes in Germany          0      3994        3194
# 2         List of dialling codes in Germany          0      4792        3994
# 3      List of islands in the Mediterranean          1       798           0
# 4         List of dialling codes in Germany          0      7168        6368
# ...                                     ...        ...       ...         ...
# 78159                           David Lynch          0         3           0
# 78160                        Toyota Corolla          0         3           0
# 78161                                Lassie          0      1547        1544
# 78162                  Macular degeneration          0      4590        4588
# 78163                   Anabasis (Xenophon)          0      1584        1583
#
#        predicted_end  predicted_score  predicted_start question_id  rank  \
# 0               1124        -0.643988             1123     wh_3810     2
# 1                335        -6.600492              335      bb_190     5
# 2               1031        -4.585421             1031      bb_190     6
# 3                680         6.828997              680      wh_289     3
# 4                404        -5.945036              404      bb_190     9
# ...              ...              ...              ...         ...   ...
# 78159              3        -8.975462                2    dpql_263     2
# 78160              3        -3.694097                2   sfq_11909     0
# 78161              3       -12.918907                3     jp_1303     2
# 78162              2       -13.325487                1    sfq_9413    10
# 78163              1       -11.334080                1   sfq_15401     2
#
#                   text_answer  text_em  text_f1
# 0                   *Dyme Def      0.0      0.0
# 1                         Bad      0.0      0.0
# 2                    Drognitz      0.0      0.0
# 3                      Sicily      1.0      1.0
# 4                    Hetzdorf      0.0      0.0
# ...                       ...      ...      ...
# 78159     redirectDavid Lynch      0.0      0.0
# 78160  redirectToyota Corolla      0.0      0.4
# 78161                   Party      0.0      0.0
# 78162           *Rosanne Barr      0.0      0.0
# 78163                   Notes      0.0      0.0
#
# [78164 rows x 12 columns]

# %%
docqa_prediction = dict()
for key, row in docqa.iterrows():
    if row['rank'] == 0:
        docqa_prediction[row['question_id']] = row['text_answer']

# %%
bert_prediction = dict()
bert_probability = dict()
for key, row in bert.iterrows():
    if row['qid'] not in bert_prediction:
        bert_prediction[row['qid']] =  row['answer']
        bert_probability[row['qid']] =  row['probability']
    
    else:
        if bert_probability[row['qid']] < row['probability']:
            bert_prediction[row['qid']] =  row['answer']
            bert_probability[row['qid']] =  row['probability']

# %%
len(wrong_howmany_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-eb0a3f470e80> in <module>
# ----> 1 len(wrong_howmany_id)
#
# NameError: name 'wrong_howmany_id' is not defined

# %%
same_wrong = 0
for instance in dev:
    if instance['QuestionId'] in wrong_when_id:
        if (instance['QuestionId'] in bert_prediction) and (instance['QuestionId'] in docqa_prediction):
            same_wrong += 1
        print("* qid: ", instance['QuestionId'])
        print("* document","/".join([file['Title'] for file in instance['EntityPages']]))
        print("* question: ", instance['Question'])
        print("* answer: ", instance['Answer']['Value'])
        if instance['QuestionId'] in bert_prediction:
            print("* prediction_bert: ", bert_prediction[instance['QuestionId']])
        else: 
            print("* prediction_bert: not predicted")
        
        if instance['QuestionId'] in docqa_prediction:
            print("* prediction_docqa: ", docqa_prediction[instance['QuestionId']])
        else:
            print("* prediction_docqa: not predicted")
            
        print("\n\n")
# Out:
# * qid:  tc_2930
# * document Ovary
# * question:  When the egg is released from the ovary, what is left behind?
# * answer:  Corpus luteum
# * prediction_bert:  nut
# * prediction_docqa:  testes
#
#
#
# * qid:  qb_6386
# * document Superstition
# * question:  According to British superstition, ‘Marry in ‘when’ and you’ll live to rue the day’?
# * answer:  May
# * prediction_bert:  today
# * prediction_docqa:  church
#
#
#
# * qid:  dpql_3210
# * document LGBT
# * question:  When people talk about LGBT rights, what does the ‘T’ represent?
# * answer:  TRANSGENDER
# * prediction_bert:  lesbian
# * prediction_docqa:  gay community
#
#
#
# * qid:  bb_5147
# * document Shoaling and schooling
# * question:  Technically a shoal of fish becomes a school of fish when it is?
# * answer:  Swimming in the same direction
# * prediction_bert: not predicted
# * prediction_docqa:  schooling
#
#
#
# * qid:  qw_5588
# * document Labour Day
# * question:  When is Labour Day in the USA, Bermuda and Canada?
# * answer:  The first Monday in September
# * prediction_bert:  1 may
# * prediction_docqa:  1942
#
#
#
# * qid:  qw_13333
# * document Manneken Pis
# * question:  When is the original version of the statue Mannekin Pis thought to have been built?
# * answer:  1388
# * prediction_bert:  14th century
# * prediction_docqa:  1965
#
#
#
# * qid:  qw_13372
# * document Maastricht Treaty/European Union/Economic and monetary union
# * question:  When the 1992 Maastricht Treaty established the European Union and led to a common currency in Europe, what was the currency called?
# * answer:  Euro
# * prediction_bert:  emu
# * prediction_docqa:  Delors Commission
#
#
#
# * qid:  qw_13383
# * document Goa'uld/Canada/Stargate SG-1/Stargate
# * question:  When did the Goa'uld first appear in the US/Canada TV series Stargate SG-1?
# * answer:  1997
# * prediction_bert: not predicted
# * prediction_docqa:  1997
#
#
#
# * qid:  sfq_2805
# * document George Washington
# * question:  When introduced into Britain in 1752, what caused a riot over eleven lost days?
# * answer:  GREGORIAN CALENDAR
# * prediction_bert:  washington's day
# * prediction_docqa:  Whiskey Rebellion
#
#
#
# * qid:  sfq_4354
# * document Australia national cricket team
# * question:  When Jim Laker took 19 wickets in the Old Trafford Test Match in 1956, who was the Australian captain?
# * answer:  RICHIE BENAUD
# * prediction_bert:  richie benaud
# * prediction_docqa:  Fred Spofforth
#
#
#
# * qid:  sfq_6142
# * document George Formby
# * question:  When George Formby sang the lines: 'It may be sticky, but I never complain, I like to have a nibble at it now and again', to what was he ostensibly referring?
# * answer:  (My Little Stick of) Blackpool Rock
# * prediction_bert:  little stick of blackpool rock
# * prediction_docqa:  ukulele or banjolele
#
#
#
# * qid:  sfq_6452
# * document Vehicle registration plate/Vehicle registration plates of the United Kingdom, Crown dependencies and overseas territories
# * question:  When suffix letters were first used on British car registration plates the letter was used for a calendar year, later, to suit the car industry, the letter changed on August 1 each year, which letter was consequently used for only seven months?
# * answer:  E
# * prediction_bert:  letter q
# * prediction_docqa:  E
#
#
#
# * qid:  sfq_8650
# * document Alexander the Great/Empire/Asian people
# * question:  When Alexander the Great had an Empire to which Asian Country did it stretch?
# * answer:  INDIA
# * prediction_bert:  india
# * prediction_docqa:  Sri
#
#
#
# * qid:  odql_465
# * document Alex Ferguson/Liverpool F.C./Premier League
# * question:  When Alex Ferguson joined Manchester United on November 6th 1986, who was manager of Liverpool?
# * answer:  KENNY DALGLISH
# * prediction_bert: not predicted
# * prediction_docqa:  Matt Busby
#
#
#
# * qid:  odql_3893
# * document Wirral Peninsula
# * question:  Accrington Stanley’s biggest league win was 8-0 in 1934 when they beat which club from the Wirral who were members of the Football League from 1923 until 1951?
# * answer:  NEW BRIGHTON
# * prediction_bert: not predicted
# * prediction_docqa:  Tranmere Rovers
#
#
#
# * qid:  odql_11176
# * document Email
# * question:  When sending an email you are given the option to 'Add Cc' or 'Add Bcc'. For which word is the 'B' the initial letter?
# * answer:  BLIND (carbon copy)
# * prediction_bert:  carbon copy
# * prediction_docqa:  E
#
#
#
# * qid:  qf_3671
# * document 17th century/19th century/Century/Piano
# * question:  When was basketball invented: 17th, 18th or 19th century?
# * answer:  19th century
# * prediction_bert:  17th century
# * prediction_docqa:  1835

# %%
print(same_wrong/len(wrong_howmany_id)*100)

# %%
len_of_answer = []
len_of_answer2 = []
known = 0
for instance in dev:
    if instance['QuestionId'] in how_id:
        print("* question: ", instance['Question'])
        print("* answer: ", instance['Answer']['Value'])
        if ("known" in instance['Question'].split()[-1]):
            known+=1
        len_of_answer.append(len(instance['Answer']['Value']))
        len_of_answer2.append(len(instance['Answer']['Value'].split()))
        if instance['QuestionId'] in bert_prediction:
            print("* prediction_bert: ", bert_prediction[instance['QuestionId']])
        else: 
            print("* prediction_bert: not predicted")
        
        if instance['QuestionId'] in docqa_prediction:
            print("* prediction_docqa: ", docqa_prediction[instance['QuestionId']])
        else:
            print("* prediction_docqa: not predicted")
            
        print("\n\n")

# %%
sum(len_of_answer)/len(how_id)
# Out:
# 10.209302325581396

# %%
sum(len_of_answer2)/len(how_id)
# Out:
# 1.8372093023255813

# %%
known/len(how_id)*100
# Out:
# 48.837209302325576

# %%
for instance in dev:
    if instance['QuestionId'] in wrong_howmany_id:
        print("* question: ", instance['Question'])
        print("* answer: ", instance['Answer']['Value'])
        if instance['QuestionId'] in bert_prediction:
            print("* prediction_bert: ", bert_prediction[instance['QuestionId']])
        else: 
            print("* prediction_bert: not predicted")
        
        if instance['QuestionId'] in docqa_prediction:
            print("* prediction_docqa: ", docqa_prediction[instance['QuestionId']])
        else:
            print("* prediction_docqa: not predicted")
            
        print("\n\n")
# Out:
# * question:  How many scottish football league teams names end in United?
# * answer:  3
# * prediction_bert:  ten
# * prediction_docqa:  4
#
#
#
# * question:  How many episodes of Prisoner: Cell Block H were made?
# * answer:  692
# * prediction_bert: not predicted
# * prediction_docqa:  16

# %%
all_qid = []

# %%
for instance in dev:
    all_qid.append(instance['QuestionId'])

# %%
right_qid = set(all_qid)-set(all_wrong)

# %%
len(right_qid), len(all_wrong)
# Out:
# (6146, 1847)

# %%
'sfq_14658' in doc_wrong
# Out:
# True

# %%
dev[0]
# Out:
# {'Answer': {'Aliases': ['Sunset Blvd',
#    'West Sunset Boulevard',
#    'Sunset Boulevard',
#    'Sunset Bulevard',
#    'Sunset Blvd.'],
#   'MatchedWikiEntityName': 'Sunset Boulevard',
#   'NormalizedAliases': ['sunset boulevard',
#    'sunset bulevard',
#    'west sunset boulevard',
#    'sunset blvd'],
#   'NormalizedMatchedWikiEntityName': 'sunset boulevard',
#   'NormalizedValue': 'sunset boulevard',
#   'Type': 'WikipediaEntity',
#   'Value': 'Sunset Boulevard'},
#  'EntityPages': [{'DocSource': 'TagMe',
#    'Filename': 'Andrew_Lloyd_Webber.txt',
#    'Title': 'Andrew Lloyd Webber'}],
#  'Question': 'Which Lloyd Webber musical premiered in the US on 10th December 1993?',
#  'QuestionId': 'tc_33',
#  'QuestionSource': 'http://www.triviacountry.com/'}

# %%
print(sample(rc_wrong,20))
# Out:
# ['sfq_16169', 'bb_8821', 'bt_2646', 'bb_2997', 'qw_15378', 'qw_15940', 'sfq_6452', 'sfq_10502', 'qw_1212', 'sfq_14777', 'jp_3355', 'jp_2757', 'bt_1031', 'qz_1230', 'qw_6358', 'qf_1414', 'qg_1921', 'qw_8714', 'bt_4062', 'qb_7482']

# %%
'tc_2699' in all_wrong
# Out:
# True

# %%
'tc_2699' in right_qid
# Out:
# False

# %%
def clearquestion(question):
    '''
    Clear the query if it contain unnecessary multiple quotes marks
    e.g) "What is the Milky Way?" --> What is the Milky Way?
    @param question
         	query string

    @return the cleaned setence
    '''
    
    if (question.startswith("\"") and question.endswith("\"")) or (question.startswith("\'") and question.endswith("\'")):
        question = question[1:-1]
        question = changepartsent("\"\"", "\"", question)
    
    return question

# %%
def changepartsent(word, reword, sentence):
    '''
    Change the part of sentence from word to reword
    @param word
         	@word that targeted to change
    @param reword
         	@word in sentence is replaced to @reword
    @param sentence
         	sentence string
    @return the changed string
    '''
    
    if type(word) is list:
        for w in word:
            sentence = sentence.replace(w,reword)

    else:
        sentence = sentence.replace(word,reword)
        sentence = sentence.replace(word[0].upper()+word[1:],reword)
    
    return sentence

# %%
candidate = ['when', 'how', 'where','what', 'which', 'who', 'how many', 'whose', 'whom', 'why']
how_words = ['many','tall','much','tall','old', 'often', 'deep', 'high', 'long', 'far', 'wide']
changelist = ['(what?)', '(what)', '(which?)', '(Which?)', '(which)', '(Which)']

# %%
wh_correct = {'tc_1468': 'none',
'tc_2090' :'who',
'qz_3320' :'none',
'qz_5487' :'what',
'qb_870' :'which',
'dpql_3976' :'how',
'wh_3910' :'which',
'bb_981' :'which',
'qw_1543' :'what',
'qw_3547' :'what',
'qw_5761' :'which',
'qw_9073' :'what',
'qw_13617' :'who',
'jp_2802' :'what',
'sfq_3556' :'none',
'sfq_11066' :'what',
'sfq_16328' :'which',
'sfq_17026' :'which',
'sfq_23865' :'which',
'odql_8345' :'who',
'odql_13281' :'who',
'odql_13821' :'who',
'odql_14537' :'what',
'bt_2301' :'which',
'bt_3655' :'who',
'qg_527' :'what',
'qg_1341' :'who',
'odql_3893': 'who',
'tc_2930': 'what',
'dpql_3210': 'what',
'qw_13372': 'what',
'sfq_2805': 'what',
'sfq_4354': 'who',
'sfq_6142': 'what',
'sfq_6452': 'which',
'sfq_8650': 'which',
'odql_465': 'who',
'odql_3893': 'which',
'odql_11176': 'which'}

# %% [markdown]
# ## WH type wrong probability

# %%
def _wh_helper(sentence):
    doc = nlp(sentence)
    
    if sentence.startswith('name'): 
        return 'what'
        #return 'name'
    
    if 'how' in sentence.split():
        list_of_words = sentence.split()
        if list_of_words.index('how') != len(list_of_words)-1: 
            next_word = list_of_words[list_of_words.index('how') + 1]
            if next_word.lower() in how_words:
                return 'how many'
    
    for w in reversed(doc):
        if w.pos_ == 'NN': continue
        else:
            for can in candidate:
                if can in w.text.split():
                    return can
            break
    
    whs = []

    for idx, token in enumerate(doc):
        for can in candidate:
            if can in token.text.split():
                return can
            
    if doc[-1].lemma_ == 'be' or doc[-1].pos_ == 'ADP':
        return 'none'
        #return 'implicit_what'
    
    if 'name' in sentence.lower():
        return 'what'
        #return 'name'
    
    return 'none'

# %%
def findWHword(sentence, qid):
    
    if qid in wh_correct:
        return wh_correct[qid]
    
    sentence = sentence.lower()
    osentence = sentence
    
    x = re.findall("\(wha.*?\)", sentence)

    if x != []:
        return 'none'
        #return 'cloze'
    
    if sentence.count('\"') > 0:
        sentence = changepartsent(re.findall(r'"([^"]*)"', sentence), 'QUOTES', sentence)
    if (sentence.count('\'')-sentence.count('\'s')) % 2 == 0 and sentence.count('\'')-sentence.count('\'s') > 0:
        sentence = changepartsent(re.findall(r"'(.*?)'", sentence), 'QUOTES', sentence)
        
    sentence = re.sub('\,.+?\,', '', sentence)
        
    wh = _wh_helper(sentence)
    if wh == 'none':
        wh = _wh_helper(osentence)
    
    return wh

# %%
candidate = ['when', 'how', 'where', 'which', 'what', 'who', 'how many', 'whose', 'whom', 'why']

# %%
whtype_dict = dict()

for can in candidate:
    whtype_dict[can] = []
whtype_dict['none'] = []
whtype_dict['implicit_what'] = []
whtype_dict['name'] = []
whtype_dict['cloze'] = []

qid_list = []
whtype_list = []
RC_solvable_list = []
RC_solvable_count = []

for instance in tqdm_notebook(dev):
    
    question = clearquestion(instance['Question'])
    whtype = findWHword(question, instance['QuestionId'])
    if whtype == 'whose' or whtype == 'whom': whtype = 'who'
    
    whtype_dict[whtype].append(instance['QuestionId'])
    
    qid_list.append(instance['QuestionId'])
    whtype_list.append(whtype)
    
    count = 0
    if not instance['QuestionId'] in wrong_bert: count += 1
    if not instance['QuestionId'] in wrong_docqa: count += 1

    RC_solvable_count.append(count)
    
    solvable = False if instance['QuestionId'] in both_wrong else True
    RC_solvable_list.append(solvable)
# Out:
# HBox(children=(IntProgress(value=0, max=7993), HTML(value='')))

# %%
del whtype_dict['whose'], whtype_dict['whom']
del whtype_dict['implicit_what'], whtype_dict['name'], whtype_dict['cloze']

# %%
# dictionary of lists  
qid_dict = {'qid': qid_list, 'whtype': whtype_list, 'RC_solvable': RC_solvable_list, 'RC_solvable_count': RC_solvable_count}

# %%
df = pd.DataFrame(qid_dict)

# %%
wrong_when_id = set(df.loc[(df.RC_solvable_count == 0) & (df.whtype == 'when')].qid)

# %%
wrong_howmany_id = set(df.loc[(df.RC_solvable_count == 0) & (df.whtype == 'how many')].qid)

# %%
len(set(df.loc[(df.whtype == 'how many')].qid))
# Out:
# 3

# %%
wrong_how_id = set(df.loc[(df.RC_solvable_count == 0) & (df.whtype == 'how')].qid)
how_id = set(df.loc[(df.whtype == 'how')].qid)

# %%
df
# Out:
#          qid whtype  RC_solvable  RC_solvable_count
# 0    tc_1250  which        False                  0
# 1    tc_1348   what         True                  1
# 2    tc_2090    who        False                  0
# 3    tc_2580  which         True                  1
# 4    tc_2957  which        False                  0
# ..       ...    ...          ...                ...
# 313  qg_1704   what        False                  0
# 314  qg_2013   what         True                  1
# 315  qg_3242  where         True                  2
# 316  qg_3854   what         True                  1
# 317  qg_4628   what        False                  0
#
# [318 rows x 4 columns]

# %%
WHtypes = ['None','how','how many','what','when','where','which','who']

# %%
WHtypes += ["ColTotal"]

# %%
# Table of survival vs passenger class
solvable_table = pd.crosstab(index=df["whtype"], 
                            columns=df["RC_solvable_count"], margins=True)


solvable_table.columns = ['0','1','2',"RowTotal"]
#solvable_table.index= WHtypes

solvable_table
# Out:
#              0     1     2  RowTotal
# whtype
# how         10    14    19        43
# how many    49    32    51       132
# none        57    27    31       115
# what       749   775  1219      2743
# when         6    19    13        38
# where       48    19    41       108
# which      729   901  1966      3596
# who        245   329   642      1216
# why          1     0     1         2
# All       1894  2116  3983      7993

# %%
solvable_table = solvable_table.drop(['All'])

# %%
# Out:
#              0     1     2  RowTotal
# whtype
# how         10    14    19        43
# how many    49    32    51       132
# none        57    27    31       115
# what       749   775  1219      2743
# when         6    19    13        38
# where       48    19    41       108
# which      729   901  1966      3596
# who        245   329   642      1216
# why          1     0     1         2
# All       1894  2116  3983      7993

# %%
solvable_table.drop(columns = ['0','1','2'])
# Out:
#           RowTotal
# whtype
# how             43
# how many       132
# none           115
# what          2743
# when            38
# where          108
# which         3596
# who           1216
# why              2
# All           7993

# %%
tmp = solvable_table.div(solvable_table["RowTotal"], axis=0)

dscore = []
for wh, instance in tmp.iterrows():
    dscore.append(instance['2']-instance['0'])

tmp['dscore'] = dscore

# %%
tmp = tmp.sort_values(['dscore'], ascending=[1])

# %%
tmp = solvable_table.div(solvable_table["RowTotal"], axis=0)
tmp = tmp.sort_values(['unsolvable'], ascending=[0])

# %%
tmp = solvable_table.div(solvable_table["RowTotal"], axis=0)
tmp = tmp.sort_values(['0'], ascending=[0])

# %%
ll = []
for idx, row in tmp.iterrows():
    ll.append((row['0'], row['1'],row['2']))

# %%
ll = []
for idx, row in tmp.iterrows():
    ll.append((row['unsolvable'], row['solvable']))

# %%
import pandas as pd
import seaborn as sns
import matplotlib
sns.set()

df = pd.DataFrame(ll, columns=['0', '1', '2'], 
                  index=tmp.index)
#df['unsolvable'] = -df['unsolvable']
ax = df.plot(title = '[TriviaQA] Difficulty per wh-type for MRQA models_triviaQA', kind='barh', stacked=True, colormap='coolwarm_r')
ax.set_facecolor("w")
matplotlib.pyplot.ylabel('wh-type')
matplotlib.pyplot.xlabel('stacked proportion of queries')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), title="# of models that gave \n  the correct answers")
ax.set_title('[TriviaQA] Difficulty per wh-type for MRQA models', fontsize=15)
# Out:
# Text(0.5, 1.0, '[TriviaQA] Difficulty per wh-type for MRQA models')

# %%
tmp.index
# Out:
# Index(['None', 'where', 'when', 'how many', 'what', 'All', 'how', 'which',
#        'who'],
#       dtype='object', name='whtype')

# %%
tmp
# Out:
#           unsolvable  solvable  RowTotal
# whtype
# None        0.481481  0.518519       1.0
# where       0.445455  0.554545       1.0
# when        0.387755  0.612245       1.0
# how many    0.370968  0.629032       1.0
# what        0.270657  0.729343       1.0
# All         0.236957  0.763043       1.0
# how         0.229508  0.770492       1.0
# which       0.202899  0.797101       1.0
# who         0.202439  0.797561       1.0

# %%
ll
# Out:
# [(0.48148148148148145, 0.5185185185185185),
#  (0.44545454545454544, 0.5545454545454546),
#  (0.3877551020408163, 0.6122448979591837),
#  (0.3709677419354839, 0.6290322580645161),
#  (0.27065736320235034, 0.7293426367976497),
#  (0.23695733767046165, 0.7630426623295383),
#  (0.22950819672131148, 0.7704918032786885),
#  (0.2028985507246377, 0.7971014492753623),
#  (0.20243902439024392, 0.7975609756097561)]

# %%
import pandas as pd
import seaborn as sns
sns.set()

df = pd.DataFrame([(0.48148148148148145, 0.5185185185185185),
 (0.44545454545454544, 0.5545454545454546),
 (0.3877551020408163, 0.6122448979591837),
 (0.3709677419354839, 0.6290322580645161),
 (0.27065736320235034, 0.7293426367976497),
 (0.23695733767046165, 0.7630426623295383),
 (0.22950819672131148, 0.7704918032786885),
 (0.2028985507246377, 0.7971014492753623),
 (0.20243902439024392, 0.7975609756097561)], columns=['unsolvable', 'solvable'], 
                  index=['None', 'where', 'how many', 'when', 'what', 'All', 'how', 'who',
       'which'])
df['unsolvable'] = -df['unsolvable']
df.plot(title = 'RCQA solvability per WH word', kind='barh', stacked=True);

# %% [markdown]
# ## LAT type wrong probability

# %%
def PosTagger(sentence):    
    '''
    POS Tagger
    
    @return the tuple of token and POS tag in sentence
    '''
    doc = nlp(sentence)
    poslist = []

    for token in doc:
        poslist.append((token.text, token.tag_, token.pos_, token.lemma_))
    
    return poslist

# %%
def detailAnsType(question):
    '''
    Find detail answer type
    
    @return the detail answer type
    '''
    st = False
    ans = ''
    PTs = PosTagger(question)
    
    #print (PTs)
    
    for idx, w in enumerate(PTs):
        if w[0].lower() == 'what' or w[0].lower() == 'which':
            st = True
            continue
        if st == True and w[0].lower() == 'did': break
#        if st == True and (w[0].lower() == 'did' or w[0].lower() == 'does' or w[0].lower() == 'do' or w[0].lower() == 'can'): break
#        if st == True and (w[2] == 'VERB' and w[3].lower() != 'be'): break
        if st == True and (w[1] == 'NN' or w[1] == 'NNP' or w[1] == 'NNS'):
            if 'kind' in w[0].lower() or 'name' in w[0].lower() or 'type' in w[0].lower() or (idx < len(PTs)-1 and "\'s" in PTs[idx+1][0].lower()):
                continue
            
            for j in range(idx, len(PTs)):
                if '’s' in PTs[j][0].lower():
                    ans = ''
                    break
                if not (PTs[j][1] == 'NN' or PTs[j][1] == 'NNP' or PTs[j][1] == 'NNS'):
                    if "\'s" in PTs[j][0].lower():
                        ans = ''
                        break
                    else: return (ans, PTs[j-1][0])
                ans += PTs[j][0]+' '
                
    
    return ("None","None")

# %%
detailAnsType('In the novel ‘Jane Eyre’ by Charlotte Bronte, what is the name of Mr Rochester’s first wife?')
# Out:
# ('wife ', 'wife')

# %%
lat_group = Counter()
lat_list = []
for instance in tqdm_notebook(dev):
    
    question = clearquestion(instance['Question'])
    lat_d, lat_s = detailAnsType(question)
    lat_list.append(lat_s)
    
    if lat_s == '’s':
        print(question)
    
    lat_group[lat_s] += 1
# Out:
# HBox(children=(IntProgress(value=0, max=7993), HTML(value='')))

# %%
qid_dict2 = {'qid': qid_list, 'whtype': whtype_list, 'lattype': lat_list, 'RC_solvable_count': RC_solvable_count}

# %%
len(set(lat_list))
# Out:
# 1600

# %%
df2 = pd.DataFrame(qid_dict2)

# %%
df2
# Out:
#           qid whtype  lattype  RC_solvable_count
# 0       tc_33  which  musical                  0
# 1       tc_40    who     None                  0
# 2       tc_49    who     None                  1
# 3       tc_56   what     None                  0
# 4      tc_106  which  actress                  2
# ...       ...    ...      ...                ...
# 7988  qg_4592    who     None                  1
# 7989  qg_4604   what       US                  1
# 7990  qg_4615    who     None                  1
# 7991  qg_4628   what   parson                  0
# 7992  qg_4656   what    sport                  2
#
# [7993 rows x 4 columns]

# %%
df_filter = df2.loc[(df2['whtype'] == 'what') | (df2['whtype'] == 'which')]

# %%
df_filter = df_filter.drop(columns=['whtype'])

# %%
counts = df_filter.groupby(['lattype','RC_solvable_count']).count()

# %%
counts_count = df_filter.groupby(['lattype','RC_solvable_count']).count()

# %%
counts_count
# Out:
#                              qid
# lattype   RC_solvable_count
# .         0                    1
# Admiral   0                    1
#           2                    1
# Adventure 2                    1
# Aircraft  1                    1
# ...                          ...
# year      2                   48
# years     0                    1
# youth     2                    1
# zoophobia 0                    1
# ‘S        2                    1
#
# [1966 rows x 1 columns]

# %%
counts = counts.unstack(level=1)
counts.columns = counts.columns.droplevel(level=0)
print (counts)
# Out:
# RC_solvable  False  True
# lattype
# .              1.0    NaN
# /songwriter    NaN    1.0
# 1970s          NaN    1.0
# A              NaN    1.0
# Act            NaN    1.0
# ...            ...    ...
# yogurt         NaN    1.0
# youth          NaN    1.0
# ’              NaN    3.0
# ’s             5.0   10.0
# “              NaN    1.0
#
# [1582 rows x 2 columns]

# %%
counts_count = counts_count.unstack(level=1)
counts_count.columns = counts_count.columns.droplevel(level=0)
print (counts_count)
# Out:
# RC_solvable_count    0   1    2
# lattype
# %                  NaN NaN  1.0
# .                  1.0 NaN  NaN
# 1940s              NaN NaN  1.0
# A                  1.0 NaN  NaN
# Act                NaN NaN  1.0
# ...                ...  ..  ...
# years              1.0 NaN  NaN
# yogurt             NaN NaN  1.0
# youth              NaN NaN  1.0
# zoophobia          1.0 NaN  NaN
# ‘S                 NaN NaN  1.0
#
# [1566 rows x 3 columns]

# %%
counts = counts.fillna(0)

# %%
counts_count = counts_count.fillna(0)
counts_count['Total'] = counts_count.sum(axis=1)

# %%
counts['Total'] = counts.sum(axis=1)

# %%
#counts1 = counts1.sort_values(['Total'], ascending=[0])
#counts2 = counts2.sort_values(['Total'], ascending=[0])
counts_count = counts_count.sort_values(['Total'], ascending=[0])
#counts_xlnet = counts_xlnet.sort_values(['Total'], ascending=[0])

# %%
counts_count
# Out:
# RC_solvable_count      0      1      2  Total
# lattype
# None               254.0  245.0  364.0  863.0
# country             67.0   92.0  290.0  449.0
# city                33.0   44.0  169.0  246.0
# film                13.0   31.0   76.0  120.0
# year                16.0   28.0   48.0   92.0
# ...                  ...    ...    ...    ...
# consist              0.0    1.0    0.0    1.0
# console              0.0    0.0    1.0    1.0
# consort              0.0    0.0    1.0    1.0
# construction         0.0    0.0    1.0    1.0
# ‘S                   0.0    0.0    1.0    1.0
#
# [1359 rows x 4 columns]

# %%
result = counts.sort_values(['Total'], ascending=[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-452c29c1ebc1> in <module>
# ----> 1 result = counts.sort_values(['Total'], ascending=[0])
#
# NameError: name 'counts' is not defined

# %%
result_sample_count = counts_count.head(100)

# %%
result_sample_count
# Out:
#                               qid  whtype  Total
# lattype    RC_solvable_count
# None       2                  364     364    728
# country    2                  290     290    580
# None       0                  254     254    508
#            1                  245     245    490
# city       2                  169     169    338
# ...                           ...     ...    ...
# creatures  2                   10      10     20
# team       1                   10      10     20
# movie      1                   10      10     20
# instrument 0                   10      10     20
# singer     1                   10      10     20
#
# [100 rows x 3 columns]

# %%
result_sample = result.head(100)

# %%
for i in range(3):
    result_sample_count[i] = result_sample_count[i]/result_sample_count['Total']
# Out:
# /home/doyeon/anaconda3/envs/qa_analysis/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
result_sample['ratio'] = result_sample[False]/result_sample['Total']
# Out:
# /home/doyeon/anaconda3/envs/kcc/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
result_sample = result_sample.sort_values(['ratio'], ascending=[0])

# %%
result_sample.columns = ['False','True','Total','Ratio']

# %%
result_sample_count
# Out:
# RC_solvable_count         0         1         2  Total
# lattype
# country            0.148889  0.204444  0.646667  450.0
# None               0.254848  0.301939  0.443213  361.0
# city               0.136546  0.176707  0.686747  249.0
# film               0.136364  0.250000  0.613636  132.0
# year               0.173913  0.304348  0.521739   92.0
# ...                     ...       ...       ...    ...
# century            0.555556  0.111111  0.333333    9.0
# duo                0.111111  0.222222  0.666667    9.0
# fish               0.333333  0.222222  0.444444    9.0
# rank               0.666667  0.111111  0.222222    9.0
# wife               0.222222  0.222222  0.555556    9.0
#
# [100 rows x 4 columns]

# %%
## 1, 0.5

import numpy as np

urgent_list = []
wrong_score_list = []
freq_list = []
freq_log_list = []
for lat, instance in result_sample_count.iterrows():    
    wrong_score = instance[0]+0.5*instance[1]
    freq_log = np.log(instance['Total'])
    freq = instance['Total']
    
    wrong_score_list.append(wrong_score)
    freq_list.append(int(freq))
    freq_log_list.append(freq_log)
    
    urgent = wrong_score*freq
    urgent_list.append(urgent)

result_sample_count['freq'] = freq_list
result_sample_count['freq_log'] = freq_log_list
result_sample_count['wrong_score'] = wrong_score_list
result_sample_count['urgent'] = urgent_list
# Out:
# /home/doyeon/anaconda3/envs/qa_analysis/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/doyeon/anaconda3/envs/qa_analysis/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/doyeon/anaconda3/envs/qa_analysis/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/doyeon/anaconda3/envs/qa_analysis/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
result_sample_count = result_sample_count.sort_values(['urgent'], ascending=[0])

# %%
result_sample_count.columns = ['0','1','2','Total','freq','freq_log','wrong_score','urgent']

# %%
result_sample_count[:10]
# Out:
#                   0         1         2  Total  freq  freq_log  wrong_score  \
# lattype
# None       0.294322  0.283893  0.421784  863.0   863  6.760415     0.436269
# country    0.149220  0.204900  0.645880  449.0   449  6.107023     0.251670
# city       0.134146  0.178862  0.686992  246.0   246  5.505332     0.223577
# film       0.108333  0.258333  0.633333  120.0   120  4.787492     0.237500
# year       0.173913  0.304348  0.521739   92.0    92  4.521789     0.326087
# state      0.200000  0.122222  0.677778   90.0    90  4.499810     0.261111
# sport      0.229730  0.270270  0.500000   74.0    74  4.304065     0.364865
# group      0.098592  0.239437  0.661972   71.0    71  4.262680     0.218310
# character  0.265625  0.203125  0.531250   64.0    64  4.158883     0.367188
# town       0.225806  0.274194  0.500000   62.0    62  4.127134     0.362903
#
#            urgent
# lattype
# None        376.5
# country     113.0
# city         55.0
# film         28.5
# year         30.0
# state        23.5
# sport        27.0
# group        15.5
# character    23.5
# town         22.5

# %%
result_sample_count['score'] = result_sample_count['2']-result_sample_count['0']
# Out:
# /home/doyeon/anaconda3/envs/qa_analysis/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
result_sample_count = result_sample_count.sort_values(['score'], ascending=[1])

# %%
import matplotlib

result_sample_count = result_sample_count[['0','1','2']]
#result_sample_alo['False'] = -result_sample_alo['False']
ax = result_sample_count.plot(figsize=(10,20), kind='barh', stacked=True , colormap='coolwarm_r')

ax.set_facecolor("w")
matplotlib.pyplot.ylabel('LAT type')
matplotlib.pyplot.xlabel('stacked proportion of questions')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), title="# of models that gave \n  the correct answers")
ax.set_title('Difficulty per LAT type for MRQA models', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Difficulty per LAT type for MRQA models')

# %%
sum(1 for i in lat_group.values() if i >= 50)
# Out:
# 17

# %%
len(result_sample)
# Out:
# 50

# %%
result_sample['False'] /= result_sample['Total']
result_sample['True'] /= result_sample['Total']

# %%
result_sample = result_sample[['False','True']]
result_sample['False'] = -result_sample['False']
result_sample.plot(figsize=(10,20), kind='barh', stacked=True ,title = 'RC solvability per LAT')
# Out:
# /home/doyeon/anaconda3/envs/kcc/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
result_sample_count = result_sample_count.sort_values([0,2,1], ascending=[0,1,1])

# %%
result_sample_count = result_sample_count[[0,1,2]]
#result_sample_alo['False'] = -result_sample_alo['False']
ax = result_sample_count.plot(figsize=(10,20), kind='barh', stacked=True , colormap='coolwarm_r')

ax.set_facecolor("w")
matplotlib.pyplot.ylabel('LAT type')
matplotlib.pyplot.xlabel('stacked proportion of queries')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), title="# of right models")
ax.set_title('Difficulty per lat type for MRQA models_triviaQA', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Difficulty per lat type for MRQA models_triviaQA')

# %%
#new & considering 4 models

qid_list = []
bidaf_solvable_list = []
bert_solvable_list = []
docqa_solvable_list = []
xlnet_solvable_list = []
lat_list = []
whtype_list = []

lat_list = []
for instance in tqdm_notebook(dev):
    
    question = clearquestion(instance['Question'])
    
    whtype = findWHword(question)    
    whtype_list.append(whtype)
    
    lat_d, lat_s = detailAnsType(question)
    lat_list.append(lat_s)
    
    qid_list.append(instance['QuestionId'])

    bert_solvable = False if instance['QuestionId'] in wrong_bert else True
    docqa_solvable = False if instance['QuestionId'] in wrong_docqa else True
                  
    bert_solvable_list.append(bert_solvable)
    docqa_solvable_list.append(docqa_solvable)

    
qid_dict = {'qid': qid_list, 'whtype':whtype_list, 'lattype': lat_list, 'bert_solvable': bert_solvable_list, 'docqa_solvable': docqa_solvable_list}
# Out:
# HBox(children=(IntProgress(value=0, max=7993), HTML(value='')))

# %%
import pandas as pd
df = pd.DataFrame(qid_dict)

# %%
qid_dict
# Out:
# {'qid': ['tc_33',
#   'tc_40',
#   'tc_49',
#   'tc_56',
#   'tc_106',
#   'tc_137',
#   'tc_217',
#   'tc_219',
#   'tc_241',
#   'tc_261',
#   'tc_267',
#   'tc_276',
#   'tc_280',
#   'tc_282',
#   'tc_288',
#   'tc_298',
#   'tc_304',
#   'tc_316',
#   'tc_349',
#   'tc_379',
#   'tc_397',
#   'tc_455',
#   'tc_510',
#   'tc_515',
#   'tc_517',
#   'tc_538',
#   'tc_540',
#   'tc_543',
#   'tc_559',
#   'tc_561',
#   'tc_564',
#   'tc_586',
#   'tc_604',
#   'tc_626',
#   'tc_635',
#   'tc_653',
#   'tc_657',
#   'tc_664',
#   'tc_665',
#   'tc_672',
#   'tc_678',
#   'tc_687',
#   'tc_704',
#   'tc_715',
#   'tc_719',
#   'tc_723',
#   'tc_731',
#   'tc_759',
#   'tc_783',
#   'tc_812',
#   'tc_827',
#   'tc_847',
#   'tc_866',
#   'tc_875',
#   'tc_881',
#   'tc_886',
#   'tc_888',
#   'tc_905',
#   'tc_938',
#   'tc_945',
#   'tc_954',
#   'tc_955',
#   'tc_962',
#   'tc_1007',
#   'tc_1008',
#   'tc_1009',
#   'tc_1020',
#   'tc_1023',
#   'tc_1028',
#   'tc_1029',
#   'tc_1068',
#   'tc_1069',
#   'tc_1070',
#   'tc_1098',
#   'tc_1114',
#   'tc_1115',
#   'tc_1120',
#   'tc_1123',
#   'tc_1124',
#   'tc_1128',
#   'tc_1131',
#   'tc_1152',
#   'tc_1156',
#   'tc_1176',
#   'tc_1179',
#   'tc_1181',
#   'tc_1183',
#   'tc_1189',
#   'tc_1210',
#   'tc_1243',
#   'tc_1250',
#   'tc_1254',
#   'tc_1313',
#   'tc_1321',
#   'tc_1324',
#   'tc_1328',
#   'tc_1331',
#   'tc_1333',
#   'tc_1340',
#   'tc_1341',
#   'tc_1348',
#   'tc_1421',
#   'tc_1442',
#   'tc_1456',
#   'tc_1468',
#   'tc_1535',
#   'tc_1542',
#   'tc_1602',
#   'tc_1606',
#   'tc_1622',
#   'tc_1623',
#   'tc_1635',
#   'tc_1693',
#   'tc_1702',
#   'tc_1704',
#   'tc_1735',
#   'tc_1754',
#   'tc_1773',
#   'tc_1798',
#   'tc_1816',
#   'tc_1826',
#   'tc_1867',
#   'tc_1888',
#   'tc_1914',
#   'tc_1924',
#   'tc_1943',
#   'tc_1944',
#   'tc_1945',
#   'tc_1968',
#   'tc_1977',
#   'tc_2020',
#   'tc_2032',
#   'tc_2090',
#   'tc_2097',
#   'tc_2111',
#   'tc_2116',
#   'tc_2128',
#   'tc_2145',
#   'tc_2167',
#   'tc_2191',
#   'tc_2202',
#   'tc_2208',
#   'tc_2236',
#   'tc_2244',
#   'tc_2250',
#   'tc_2252',
#   'tc_2256',
#   'tc_2257',
#   'tc_2265',
#   'tc_2270',
#   'tc_2295',
#   'tc_2299',
#   'tc_2300',
#   'tc_2306',
#   'tc_2331',
#   'tc_2350',
#   'tc_2359',
#   'tc_2380',
#   'tc_2417',
#   'tc_2454',
#   'tc_2457',
#   'tc_2496',
#   'tc_2499',
#   'tc_2505',
#   'tc_2506',
#   'tc_2524',
#   'tc_2544',
#   'tc_2556',
#   'tc_2564',
#   'tc_2573',
#   'tc_2580',
#   'tc_2644',
#   'tc_2669',
#   'tc_2677',
#   'tc_2687',
#   'tc_2699',
#   'tc_2728',
#   'tc_2736',
#   'tc_2740',
#   'tc_2744',
#   'tc_2758',
#   'tc_2767',
#   'tc_2816',
#   'tc_2818',
#   'tc_2829',
#   'tc_2833',
#   'tc_2834',
#   'tc_2836',
#   'tc_2841',
#   'tc_2849',
#   'tc_2850',
#   'tc_2900',
#   'tc_2901',
#   'tc_2914',
#   'tc_2926',
#   'tc_2930',
#   'tc_2957',
#   'tc_2973',
#   'tc_3033',
#   'tc_3070',
#   'tc_3120',
#   'tc_3129',
#   'tc_3130',
#   'tc_3155',
#   'qz_63',
#   'qz_68',
#   'qz_76',
#   'qz_78',
#   'qz_107',
#   'qz_122',
#   'qz_127',
#   'qz_135',
#   'qz_147',
#   'qz_148',
#   'qz_186',
#   'qz_188',
#   'qz_196',
#   'qz_204',
#   'qz_267',
#   'qz_298',
#   'qz_340',
#   'qz_351',
#   'qz_374',
#   'qz_385',
#   'qz_418',
#   'qz_429',
#   'qz_430',
#   'qz_438',
#   'qz_453',
#   'qz_547',
#   'qz_603',
#   'qz_608',
#   'qz_611',
#   'qz_620',
#   'qz_644',
#   'qz_647',
#   'qz_664',
#   'qz_685',
#   'qz_688',
#   'qz_690',
#   'qz_726',
#   'qz_737',
#   'qz_755',
#   'qz_757',
#   'qz_832',
#   'qz_847',
#   'qz_848',
#   'qz_860',
#   'qz_866',
#   'qz_881',
#   'qz_921',
#   'qz_952',
#   'qz_1032',
#   'qz_1046',
#   'qz_1064',
#   'qz_1074',
#   'qz_1086',
#   'qz_1111',
#   'qz_1112',
#   'qz_1128',
#   'qz_1130',
#   'qz_1141',
#   'qz_1173',
#   'qz_1189',
#   'qz_1191',
#   'qz_1197',
#   'qz_1221',
#   'qz_1230',
#   'qz_1249',
#   'qz_1291',
#   'qz_1354',
#   'qz_1357',
#   'qz_1380',
#   'qz_1382',
#   'qz_1384',
#   'qz_1393',
#   'qz_1417',
#   'qz_1429',
#   'qz_1453',
#   'qz_1516',
#   'qz_1545',
#   'qz_1572',
#   'qz_1603',
#   'qz_1631',
#   'qz_1670',
#   'qz_1684',
#   'qz_1690',
#   'qz_1693',
#   'qz_1720',
#   'qz_1725',
#   'qz_1730',
#   'qz_1745',
#   'qz_1794',
#   'qz_1797',
#   'qz_1825',
#   'qz_1858',
#   'qz_1872',
#   'qz_1882',
#   'qz_1915',
#   'qz_1918',
#   'qz_1952',
#   'qz_1958',
#   'qz_2001',
#   'qz_2018',
#   'qz_2029',
#   'qz_2053',
#   'qz_2090',
#   'qz_2111',
#   'qz_2131',
#   'qz_2135',
#   'qz_2165',
#   'qz_2176',
#   'qz_2217',
#   'qz_2223',
#   'qz_2225',
#   'qz_2231',
#   'qz_2260',
#   'qz_2280',
#   'qz_2289',
#   'qz_2291',
#   'qz_2309',
#   'qz_2324',
#   'qz_2379',
#   'qz_2384',
#   'qz_2419',
#   'qz_2423',
#   'qz_2428',
#   'qz_2430',
#   'qz_2440',
#   'qz_2444',
#   'qz_2458',
#   'qz_2466',
#   'qz_2471',
#   'qz_2478',
#   'qz_2532',
#   'qz_2538',
#   'qz_2562',
#   'qz_2564',
#   'qz_2589',
#   'qz_2594',
#   'qz_2619',
#   'qz_2654',
#   'qz_2713',
#   'qz_2717',
#   'qz_2749',
#   'qz_2758',
#   'qz_2768',
#   'qz_2784',
#   'qz_2789',
#   'qz_2821',
#   'qz_2822',
#   'qz_2835',
#   'qz_2845',
#   'qz_2853',
#   'qz_2866',
#   'qz_2884',
#   'qz_2908',
#   'qz_2980',
#   'qz_2999',
#   'qz_3023',
#   'qz_3027',
#   'qz_3040',
#   'qz_3041',
#   'qz_3042',
#   'qz_3101',
#   'qz_3127',
#   'qz_3130',
#   'qz_3152',
#   'qz_3154',
#   'qz_3159',
#   'qz_3236',
#   'qz_3237',
#   'qz_3320',
#   'qz_3358',
#   'qz_3393',
#   'qz_3397',
#   'qz_3432',
#   'qz_3440',
#   'qz_3456',
#   'qz_3477',
#   'qz_3479',
#   'qz_3504',
#   'qz_3569',
#   'qz_3570',
#   'qz_3588',
#   'qz_3623',
#   'qz_3708',
#   'qz_3736',
#   'qz_3741',
#   'qz_3745',
#   'qz_3752',
#   'qz_3760',
#   'qz_3775',
#   'qz_3777',
#   'qz_3780',
#   'qz_3781',
#   'qz_3833',
#   'qz_3863',
#   'qz_3878',
#   'qz_3895',
#   'qz_3898',
#   'qz_3903',
#   'qz_3911',
#   'qz_3920',
#   'qz_3923',
#   'qz_3927',
#   'qz_3968',
#   'qz_3969',
#   'qz_3971',
#   'qz_3995',
#   'qz_4002',
#   'qz_4005',
#   'qz_4056',
#   'qz_4061',
#   'qz_4093',
#   'qz_4101',
#   'qz_4121',
#   'qz_4127',
#   'qz_4140',
#   'qz_4151',
#   'qz_4171',
#   'qz_4224',
#   'qz_4226',
#   'qz_4231',
#   'qz_4240',
#   'qz_4267',
#   'qz_4308',
#   'qz_4311',
#   'qz_4322',
#   'qz_4414',
#   'qz_4417',
#   'qz_4432',
#   'qz_4443',
#   'qz_4450',
#   'qz_4493',
#   'qz_4540',
#   'qz_4548',
#   'qz_4565',
#   'qz_4575',
#   'qz_4576',
#   'qz_4585',
#   'qz_4606',
#   'qz_4637',
#   'qz_4638',
#   'qz_4642',
#   'qz_4706',
#   'qz_4745',
#   'qz_4861',
#   'qz_4910',
#   'qz_4911',
#   'qz_4923',
#   'qz_4945',
#   'qz_4979',
#   'qz_4991',
#   'qz_4992',
#   'qz_5039',
#   'qz_5042',
#   'qz_5044',
#   'qz_5050',
#   'qz_5053',
#   'qz_5075',
#   'qz_5082',
#   'qz_5083',
#   'qz_5084',
#   'qz_5143',
#   'qz_5172',
#   'qz_5202',
#   'qz_5203',
#   'qz_5217',
#   'qz_5235',
#   'qz_5236',
#   'qz_5252',
#   'qz_5270',
#   'qz_5300',
#   'qz_5301',
#   'qz_5341',
#   'qz_5409',
#   'qz_5420',
#   'qz_5459',
#   'qz_5461',
#   'qz_5462',
#   'qz_5487',
#   'qz_5489',
#   'qz_5493',
#   'qz_5496',
#   'qz_5511',
#   'qz_5520',
#   'qz_5552',
#   'qz_5554',
#   'qz_5580',
#   'qz_5584',
#   'qz_5598',
#   'qz_5614',
#   'qz_5645',
#   'qz_5670',
#   'qz_5674',
#   'qz_5684',
#   'qz_5728',
#   'qz_5790',
#   'qz_5795',
#   'qz_5796',
#   'qz_5801',
#   'qz_5812',
#   'qz_5867',
#   'qz_5870',
#   'qz_5877',
#   'qz_5894',
#   'qz_5898',
#   'qz_5918',
#   'qz_5919',
#   'qz_5950',
#   'qz_5999',
#   'qz_6028',
#   'qz_6036',
#   'qz_6077',
#   'qz_6079',
#   'qz_6127',
#   'qz_6128',
#   'qz_6186',
#   'qz_6215',
#   'qz_6235',
#   'qz_6268',
#   'qz_6273',
#   'qz_6316',
#   'qz_6389',
#   'qz_6391',
#   'qz_6393',
#   'qz_6396',
#   'qz_6456',
#   'qz_6596',
#   'qz_6607',
#   'qz_6626',
#   'qz_6685',
#   'qz_6687',
#   'qz_6713',
#   'qz_6727',
#   'qz_6774',
#   'qz_6778',
#   'qz_6806',
#   'qz_6819',
#   'qz_6827',
#   'qz_6834',
#   'qz_6851',
#   'qz_6898',
#   'qb_34',
#   'qb_41',
#   'qb_66',
#   'qb_76',
#   'qb_84',
#   'qb_92',
#   'qb_104',
#   'qb_107',
#   'qb_151',
#   'qb_153',
#   'qb_158',
#   'qb_162',
#   'qb_163',
#   'qb_189',
#   'qb_192',
#   'qb_203',
#   'qb_207',
#   'qb_218',
#   'qb_241',
#   'qb_250',
#   'qb_254',
#   'qb_255',
#   'qb_260',
#   'qb_274',
#   'qb_275',
#   'qb_280',
#   'qb_292',
#   'qb_299',
#   'qb_304',
#   'qb_306',
#   'qb_354',
#   'qb_355',
#   'qb_361',
#   'qb_365',
#   'qb_370',
#   'qb_382',
#   'qb_403',
#   'qb_404',
#   'qb_417',
#   'qb_446',
#   'qb_468',
#   'qb_482',
#   'qb_495',
#   'qb_498',
#   'qb_503',
#   'qb_511',
#   'qb_525',
#   'qb_532',
#   'qb_547',
#   'qb_558',
#   'qb_565',
#   'qb_571',
#   'qb_574',
#   'qb_578',
#   'qb_590',
#   'qb_603',
#   'qb_606',
#   'qb_622',
#   'qb_628',
#   'qb_637',
#   'qb_640',
#   'qb_650',
#   'qb_669',
#   'qb_688',
#   'qb_711',
#   'qb_712',
#   'qb_720',
#   'qb_722',
#   'qb_723',
#   'qb_727',
#   'qb_733',
#   'qb_738',
#   'qb_748',
#   'qb_765',
#   'qb_766',
#   'qb_770',
#   'qb_777',
#   'qb_779',
#   'qb_801',
#   'qb_804',
#   'qb_811',
#   'qb_815',
#   'qb_816',
#   'qb_866',
#   'qb_870',
#   'qb_883',
#   'qb_891',
#   'qb_907',
#   'qb_915',
#   'qb_916',
#   'qb_919',
#   'qb_925',
#   'qb_930',
#   'qb_936',
#   'qb_941',
#   'qb_950',
#   'qb_966',
#   'qb_980',
#   'qb_1009',
#   'qb_1010',
#   'qb_1030',
#   'qb_1032',
#   'qb_1050',
#   'qb_1147',
#   'qb_1166',
#   'qb_1167',
#   'qb_1172',
#   'qb_1175',
#   'qb_1179',
#   'qb_1191',
#   'qb_1204',
#   'qb_1227',
#   'qb_1235',
#   'qb_1253',
#   'qb_1261',
#   'qb_1285',
#   'qb_1294',
#   'qb_1299',
#   'qb_1329',
#   'qb_1340',
#   'qb_1373',
#   'qb_1379',
#   'qb_1383',
#   'qb_1414',
#   'qb_1415',
#   'qb_1429',
#   'qb_1431',
#   'qb_1435',
#   'qb_1438',
#   'qb_1448',
#   'qb_1456',
#   'qb_1462',
#   'qb_1494',
#   'qb_1495',
#   'qb_1502',
#   'qb_1522',
#   'qb_1538',
#   'qb_1556',
#   'qb_1557',
#   'qb_1569',
#   'qb_1580',
#   'qb_1647',
#   'qb_1652',
#   'qb_1750',
#   'qb_1751',
#   'qb_1757',
#   'qb_1762',
#   'qb_1767',
#   'qb_1768',
#   'qb_1812',
#   'qb_1825',
#   'qb_1830',
#   'qb_1850',
#   'qb_1861',
#   'qb_1944',
#   'qb_1993',
#   'qb_2016',
#   'qb_2020',
#   'qb_2047',
#   'qb_2071',
#   'qb_2091',
#   'qb_2122',
#   'qb_2123',
#   'qb_2148',
#   'qb_2151',
#   'qb_2169',
#   'qb_2184',
#   'qb_2199',
#   'qb_2215',
#   'qb_2221',
#   'qb_2234',
#   'qb_2271',
#   'qb_2279',
#   'qb_2308',
#   'qb_2344',
#   'qb_2350',
#   'qb_2359',
#   'qb_2363',
#   'qb_2370',
#   'qb_2377',
#   'qb_2381',
#   'qb_2393',
#   'qb_2397',
#   'qb_2428',
#   'qb_2456',
#   'qb_2457',
#   'qb_2461',
#   'qb_2483',
#   'qb_2496',
#   'qb_2497',
#   'qb_2498',
#   'qb_2514',
#   'qb_2537',
#   'qb_2545',
#   'qb_2546',
#   'qb_2551',
#   'qb_2563',
#   'qb_2589',
#   'qb_2601',
#   'qb_2604',
#   'qb_2621',
#   'qb_2640',
#   'qb_2647',
#   'qb_2687',
#   'qb_2689',
#   'qb_2701',
#   'qb_2710',
#   'qb_2712',
#   'qb_2743',
#   'qb_2760',
#   'qb_2764',
#   'qb_2774',
#   'qb_2782',
#   'qb_2805',
#   'qb_2823',
#   'qb_2833',
#   'qb_2848',
#   'qb_2850',
#   'qb_2854',
#   'qb_2869',
#   'qb_2870',
#   'qb_2880',
#   'qb_2893',
#   'qb_2899',
#   'qb_2901',
#   'qb_2902',
#   'qb_2909',
#   'qb_2925',
#   'qb_2926',
#   'qb_2928',
#   'qb_2932',
#   'qb_2934',
#   'qb_2935',
#   'qb_2957',
#   'qb_2975',
#   'qb_2981',
#   'qb_2990',
#   'qb_3003',
#   'qb_3029',
#   'qb_3042',
#   'qb_3065',
#   'qb_3068',
#   'qb_3073',
#   'qb_3078',
#   'qb_3085',
#   'qb_3092',
#   'qb_3093',
#   'qb_3103',
#   'qb_3129',
#   'qb_3137',
#   'qb_3147',
#   'qb_3160',
#   'qb_3168',
#   'qb_3180',
#   'qb_3183',
#   'qb_3191',
#   'qb_3192',
#   'qb_3200',
#   'qb_3225',
#   'qb_3248',
#   'qb_3296',
#   'qb_3300',
#   'qb_3320',
#   'qb_3329',
#   'qb_3343',
#   'qb_3365',
#   'qb_3378',
#   'qb_3379',
#   'qb_3427',
#   'qb_3462',
#   'qb_3466',
#   'qb_3486',
#   'qb_3494',
#   'qb_3500',
#   'qb_3501',
#   'qb_3510',
#   'qb_3516',
#   'qb_3523',
#   'qb_3535',
#   'qb_3548',
#   'qb_3553',
#   'qb_3556',
#   'qb_3565',
#   'qb_3569',
#   'qb_3573',
#   'qb_3577',
#   'qb_3581',
#   'qb_3614',
#   'qb_3618',
#   'qb_3620',
#   'qb_3644',
#   'qb_3648',
#   'qb_3652',
#   'qb_3684',
#   'qb_3697',
#   'qb_3702',
#   'qb_3740',
#   'qb_3767',
#   'qb_3768',
#   'qb_3775',
#   'qb_3790',
#   'qb_3791',
#   'qb_3798',
#   'qb_3803',
#   'qb_3821',
#   'qb_3822',
#   'qb_3830',
#   'qb_3849',
#   'qb_3855',
#   'qb_3869',
#   'qb_3878',
#   'qb_3880',
#   'qb_3887',
#   'qb_3917',
#   'qb_3930',
#   'qb_3940',
#   'qb_4010',
#   'qb_4011',
#   'qb_4014',
#   'qb_4016',
#   'qb_4017',
#   'qb_4021',
#   'qb_4040',
#   'qb_4053',
#   'qb_4064',
#   'qb_4066',
#   'qb_4106',
#   'qb_4125',
#   'qb_4130',
#   'qb_4151',
#   'qb_4157',
#   'qb_4163',
#   'qb_4169',
#   'qb_4173',
#   'qb_4219',
#   'qb_4220',
#   'qb_4225',
#   'qb_4246',
#   'qb_4264',
#   'qb_4281',
#   'qb_4284',
#   'qb_4289',
#   'qb_4294',
#   'qb_4301',
#   'qb_4306',
#   'qb_4325',
#   'qb_4336',
#   'qb_4353',
#   'qb_4358',
#   'qb_4368',
#   'qb_4373',
#   'qb_4391',
#   'qb_4395',
#   'qb_4397',
#   'qb_4415',
#   'qb_4427',
#   'qb_4442',
#   'qb_4444',
#   'qb_4446',
#   'qb_4470',
#   'qb_4482',
#   'qb_4501',
#   'qb_4528',
#   'qb_4532',
#   'qb_4548',
#   'qb_4550',
#   'qb_4561',
#   'qb_4569',
#   'qb_4576',
#   'qb_4589',
#   'qb_4594',
#   'qb_4606',
#   'qb_4612',
#   'qb_4664',
#   'qb_4673',
#   'qb_4681',
#   'qb_4693',
#   'qb_4695',
#   'qb_4697',
#   'qb_4699',
#   'qb_4710',
#   'qb_4717',
#   'qb_4719',
#   'qb_4726',
#   'qb_4727',
#   'qb_4738',
#   'qb_4745',
#   'qb_4761',
#   'qb_4763',
#   'qb_4786',
#   'qb_4792',
#   'qb_4795',
#   'qb_4796',
#   'qb_4801',
#   'qb_4849',
#   'qb_4863',
#   'qb_4901',
#   'qb_4911',
#   'qb_4919',
#   'qb_4948',
#   'qb_4949',
#   'qb_4950',
#   'qb_4987',
#   'qb_5031',
#   'qb_5063',
#   'qb_5070',
#   'qb_5097',
#   'qb_5098',
#   'qb_5115',
#   'qb_5124',
#   'qb_5137',
#   'qb_5139',
#   'qb_5157',
#   'qb_5175',
#   'qb_5181',
#   'qb_5182',
#   'qb_5184',
#   'qb_5204',
#   'qb_5209',
#   'qb_5216',
#   'qb_5224',
#   'qb_5231',
#   'qb_5233',
#   'qb_5234',
#   'qb_5271',
#   'qb_5281',
#   'qb_5285',
#   'qb_5286',
#   'qb_5345',
#   'qb_5354',
#   'qb_5361',
#   'qb_5388',
#   'qb_5390',
#   'qb_5398',
#   'qb_5400',
#   'qb_5408',
#   'qb_5427',
#   'qb_5431',
#   'qb_5444',
#   'qb_5458',
#   'qb_5498',
#   'qb_5502',
#   'qb_5520',
#   'qb_5532',
#   'qb_5538',
#   'qb_5539',
#   'qb_5541',
#   'qb_5544',
#   'qb_5547',
#   'qb_5564',
#   'qb_5565',
#   'qb_5582',
#   'qb_5590',
#   'qb_5601',
#   'qb_5615',
#   'qb_5618',
#   ...],
#  'whtype': ['which',
#   'who',
#   'who',
#   'what',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'who',
#   'who',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'what',
#   'what',
#   'which',
#   'who',
#   'who',
#   'which',
#   'which',
#   'which',
#   'where',
#   'what',
#   'where',
#   'who',
#   'which',
#   'where',
#   'how',
#   'which',
#   'which',
#   'how',
#   'which',
#   'who',
#   'who',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'who',
#   'who',
#   'what',
#   'who',
#   'which',
#   'what',
#   'which',
#   'who',
#   'who',
#   'who',
#   'which',
#   'what',
#   'which',
#   'what',
#   'who',
#   'how many',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'what',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'who',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'how',
#   'which',
#   'who',
#   'which',
#   'which',
#   'who',
#   'what',
#   'what',
#   'who',
#   'who',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'who',
#   'who',
#   'who',
#   'which',
#   'which',
#   'how many',
#   'what',
#   'which',
#   'which',
#   'who',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'who',
#   'which',
#   'who',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'what',
#   'where',
#   'who',
#   'which',
#   'what',
#   'which',
#   'which',
#   'what',
#   'who',
#   'how many',
#   'which',
#   'how',
#   'which',
#   'who',
#   'who',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'what',
#   'who',
#   'what',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'which',
#   'what',
#   'what',
#   'what',
#   'what',
#   'what',
#   'which',
#   'what',
#   'which',
#   'what',
#   'where',
#   'what',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'which',
#   'what',
#   'how many',
#   'what',
#   'when',
#   'which',
#   'what',
#   'which',
#   'which',
#   'who',
#   'which',
#   'what',
#   'which',
#   'what',
#   'what',
#   'what',
#   'what',
#   'who',
#   'how many',
#   'what',
#   'who',
#   'what',
#   'what',
#   'what',
#   'what',
#   'how many',
#   'what',
#   'which',
#   'which',
#   'who',
#   'None',
#   'what',
#   'what',
#   'what',
#   'what',
#   'what',
#   'which',
#   'what',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'who',
#   'who',
#   'which',
#   'what',
#   'who',
#   'which',
#   'what',
#   'what',
#   'what',
#   'how many',
#   'who',
#   'what',
#   'how many',
#   'who',
#   'which',
#   'how',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'who',
#   'what',
#   'which',
#   'who',
#   'which',
#   'how many',
#   'what',
#   'what',
#   'which',
#   'what',
#   'what',
#   'what',
#   'who',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'what',
#   'who',
#   'what',
#   'which',
#   'which',
#   'which',
#   'who',
#   'what',
#   'who',
#   'which',
#   'how',
#   'who',
#   'what',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'how',
#   'who',
#   'which',
#   'who',
#   'which',
#   'what',
#   'what',
#   'which',
#   'which',
#   'which',
#   'how',
#   'which',
#   'who',
#   'which',
#   'who',
#   'who',
#   'which',
#   'what',
#   'who',
#   'which',
#   'what',
#   'who',
#   'who',
#   'who',
#   'who',
#   'what',
#   'who',
#   'who',
#   'what',
#   'how many',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'who',
#   'which',
#   'who',
#   'who',
#   'which',
#   'who',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'which',
#   'which',
#   'who',
#   'who',
#   'who',
#   'what',
#   'which',
#   'what',
#   'who',
#   'which',
#   'which',
#   'what',
#   'what',
#   'when',
#   'who',
#   'which',
#   'who',
#   'who',
#   'which',
#   'how',
#   'which',
#   'who',
#   'who',
#   'what',
#   'which',
#   'what',
#   'which',
#   'which',
#   'who',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'who',
#   'what',
#   'how many',
#   'how many',
#   'which',
#   'who',
#   'what',
#   'who',
#   'how many',
#   'which',
#   'which',
#   'which',
#   'which',
#   'how',
#   'who',
#   'what',
#   'which',
#   'what',
#   'what',
#   'which',
#   'who',
#   'who',
#   'what',
#   'who',
#   'what',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'who',
#   'how',
#   'who',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'where',
#   'how',
#   'which',
#   'which',
#   'which',
#   'who',
#   'what',
#   'which',
#   'who',
#   'which',
#   'which',
#   'what',
#   'what',
#   'None',
#   'who',
#   'which',
#   'who',
#   'which',
#   'who',
#   'which',
#   'what',
#   'how many',
#   'which',
#   'which',
#   'what',
#   'who',
#   'which',
#   'what',
#   'who',
#   'what',
#   'what',
#   'what',
#   'which',
#   'what',
#   'which',
#   'None',
#   'which',
#   'what',
#   'who',
#   'who',
#   'what',
#   'who',
#   'which',
#   'what',
#   'what',
#   'what',
#   'who',
#   'which',
#   'which',
#   'who',
#   'which',
#   'who',
#   'which',
#   'who',
#   'who',
#   'what',
#   'who',
#   'which',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'what',
#   'what',
#   'which',
#   'who',
#   'where',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'what',
#   'which',
#   'who',
#   'who',
#   'what',
#   'what',
#   'which',
#   'what',
#   'who',
#   'which',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'what',
#   'which',
#   'where',
#   'what',
#   'how many',
#   'what',
#   'what',
#   'what',
#   'what',
#   'what',
#   'what',
#   'how many',
#   'what',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'how many',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'who',
#   'how many',
#   'which',
#   'what',
#   'what',
#   'who',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'what',
#   'what',
#   'which',
#   'which',
#   'who',
#   'which',
#   'who',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'who',
#   'what',
#   'who',
#   'what',
#   'what',
#   'what',
#   'what',
#   'which',
#   'what',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'which',
#   'what',
#   'which',
#   'which',
#   'who',
#   'how many',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'how many',
#   'which',
#   'how many',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'which',
#   'how many',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'who',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'what',
#   'which',
#   'which',
#   'who',
#   'what',
#   'what',
#   'who',
#   'which',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'how many',
#   'who',
#   'what',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'what',
#   'which',
#   'what',
#   'who',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'how many',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'who',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'who',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'how many',
#   'which',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'what',
#   'what',
#   'what',
#   'which',
#   'who',
#   'who',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'who',
#   'which',
#   'what',
#   'what',
#   'who',
#   'which',
#   'what',
#   'who',
#   'which',
#   'which',
#   'what',
#   'which',
#   'who',
#   'which',
#   'what',
#   'which',
#   'what',
#   'which',
#   'who',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'who',
#   'what',
#   'which',
#   'what',
#   'who',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'which',
#   'who',
#   'which',
#   'which',
#   'which',
#   'who',
#   'what',
#   'who',
#   'who',
#   'which',
#   'which',
#   'which',
#   'how many',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'which',
#   'who',
#   'who',
#   'what',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'which',
#   'what',
#   'what',
#   'what',
#   'which',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'who',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'what',
#   'what',
#   'who',
#   'what',
#   'what',
#   'which',
#   'who',
#   'which',
#   'how many',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'which',
#   'which',
#   'what',
#   'which',
#   'what',
#   'what',
#   'which',
#   'which',
#   'who',
#   'which',
#   'what',
#   'what',
#   'what',
#   'what',
#   'which',
#   'which',
#   'who',
#   'who',
#   'who',
#   'who',
#   'what',
#   'what',
#   'what',
#   'which',
#   'what',
#   'who',
#   'what',
#   'what',
#   'which',
#   'who',
#   'who',
#   'which',
#   'which',
#   'which',
#   'how many',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'what',
#   'which',
#   'which',
#   'how many',
#   'which',
#   'which',
#   'which',
#   'which',
#   'who',
#   'what',
#   'what',
#   'which',
#   'which',
#   'who',
#   'which',
#   'which',
#   'who',
#   'when',
#   'what',
#   'what',
#   'which',
#   'which',
#   'what',
#   ...],
#  'lattype': ['Webber',
#   'None',
#   'None',
#   'life',
#   'actress',
#   'autobiography',
#   'volcano',
#   'color',
#   'country',
#   'song',
#   'None',
#   'None',
#   'None',
#   'group',
#   'highway',
#   'country',
#   'series',
#   'show',
#   'novel',
#   'stepfather',
#   'None',
#   'movie',
#   'None',
#   'profession',
#   'None',
#   'None',
#   'country',
#   'sport',
#   'song',
#   'None',
#   'movie',
#   'None',
#   'None',
#   'musician',
#   'None',
#   'None',
#   'Brit',
#   'state',
#   'None',
#   'movie',
#   'None',
#   'None',
#   'country',
#   'US',
#   'movie',
#   'David',
#   'city',
#   'movie',
#   'Lancaster',
#   'None',
#   'None',
#   'Company',
#   'None',
#   'journalist',
#   'Terence',
#   'drink',
#   'None',
#   'None',
#   'Ben',
#   'show',
#   'date',
#   'country',
#   'profession',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'None',
#   'Hillary',
#   'state',
#   'country',
#   'None',
#   'star',
#   'star',
#   'character',
#   'president',
#   'movie',
#   'director',
#   'classic',
#   'King',
#   'actress',
#   'Oscar',
#   'career',
#   'actor',
#   'dancer',
#   'brothel',
#   'None',
#   'relation',
#   'world',
#   'country',
#   'river',
#   'event',
#   'None',
#   'movie',
#   'None',
#   'country',
#   'country',
#   'None',
#   'item',
#   'None',
#   'None',
#   'None',
#   'Sampras',
#   'sport',
#   'team',
#   'movie',
#   'star',
#   'sitcom',
#   'None',
#   'None',
#   'None',
#   'team',
#   'slam',
#   'None',
#   'Spam',
#   'country',
#   'year',
#   'None',
#   'UK',
#   'Sea',
#   'star',
#   'country',
#   'Fatah',
#   'country',
#   'country',
#   'founders',
#   'Folles',
#   'war',
#   'percentage',
#   'home',
#   'None',
#   'actress',
#   'None',
#   'label',
#   'label',
#   'wife',
#   'city',
#   'singer',
#   'letters',
#   'None',
#   'None',
#   'President',
#   'disaster',
#   'state',
#   'state',
#   'month',
#   'None',
#   'None',
#   'city',
#   'None',
#   'crusader',
#   'None',
#   'None',
#   'conductor',
#   'writer',
#   'year',
#   'terminus',
#   'pass',
#   'group',
#   'None',
#   'language',
#   'Square',
#   'country',
#   'crusade',
#   'city',
#   'battle',
#   'None',
#   'wife',
#   'country',
#   'Party',
#   'plurality',
#   'word',
#   'builder',
#   'Piaf',
#   'material',
#   'organism',
#   'material',
#   'change',
#   'branch',
#   'force',
#   'reptile',
#   'seaweed',
#   'None',
#   'substance',
#   'family',
#   'study',
#   'rodent',
#   'vein',
#   'mammal',
#   'teeth',
#   'pancreas',
#   'None',
#   'buttock',
#   'None',
#   'hormone',
#   'gas',
#   'substance',
#   'mineral',
#   'None',
#   'planet',
#   'Way',
#   'force',
#   'film',
#   'element',
#   'colour',
#   'number',
#   'None',
#   'None',
#   'colour',
#   'None',
#   'number',
#   'team',
#   'attraction',
#   'acid',
#   'None',
#   'acronym',
#   'year',
#   'line',
#   'None',
#   'None',
#   'Nobel',
#   'city',
#   'letter',
#   'Spice',
#   'notes',
#   'country',
#   'novel',
#   'word',
#   'city',
#   'country',
#   'nephews',
#   'film',
#   'word',
#   'game',
#   'bone',
#   'film',
#   'show',
#   'animal',
#   'None',
#   'None',
#   'killer',
#   'score',
#   'None',
#   'song',
#   'name',
#   'Kevin',
#   'word',
#   'None',
#   'None',
#   'word',
#   'None',
#   'None',
#   'gymnast',
#   'None',
#   'actor',
#   'brand',
#   'animal',
#   'country',
#   'type',
#   'King',
#   'film',
#   'Channel',
#   'device',
#   'colour',
#   'bee',
#   'None',
#   'ingredient',
#   'year',
#   'None',
#   'film',
#   'None',
#   'None',
#   'animal',
#   'city',
#   'woman',
#   'event',
#   'city',
#   'None',
#   'speech',
#   'nationality',
#   'film',
#   'act',
#   'team',
#   'friend',
#   'animal',
#   'home',
#   'marsupial',
#   'None',
#   'animal',
#   'sport',
#   'newspaper',
#   'book',
#   'None',
#   'pub',
#   'None',
#   'actress',
#   'None',
#   'None',
#   'animal',
#   'mammals',
#   'poet',
#   'scientist',
#   'Ruddock',
#   'city',
#   'Club',
#   'neighbours',
#   'presents',
#   'None',
#   'None',
#   'planet',
#   'None',
#   'None',
#   'None',
#   'bit',
#   'sea',
#   'billionaire',
#   'club',
#   'None',
#   'author',
#   'None',
#   'year',
#   'None',
#   'None',
#   'band',
#   'shape',
#   'None',
#   'film',
#   'character',
#   'None',
#   'None',
#   'None',
#   'None',
#   'station',
#   'None',
#   'None',
#   'Cobblepot',
#   'None',
#   'cowboy',
#   'movie',
#   'None',
#   'economist',
#   'house',
#   'dragon',
#   'robber',
#   'band',
#   'butler',
#   'None',
#   'country',
#   'None',
#   'None',
#   'country',
#   'None',
#   'organ',
#   'killer',
#   'school',
#   'painting',
#   'year',
#   'couple',
#   'murderer',
#   'None',
#   'None',
#   'None',
#   'kangaroo',
#   'country',
#   'None',
#   'None',
#   'town',
#   'movie',
#   'Lewis',
#   'None',
#   'None',
#   'None',
#   'B',
#   'None',
#   'None',
#   'magazine',
#   'None',
#   'part',
#   'None',
#   'None',
#   'nationality',
#   'Winter',
#   'plains',
#   'Canadian',
#   'originates',
#   'None',
#   'None',
#   'player',
#   'West',
#   'character',
#   'year',
#   'cat',
#   'comedy',
#   'comedy',
#   'country',
#   'None',
#   'None',
#   'None',
#   'None',
#   'area',
#   'None',
#   'story',
#   'None',
#   'None',
#   'colour',
#   'golf',
#   'actress',
#   'club',
#   'None',
#   'None',
#   'enzyme',
#   'cheese',
#   'year',
#   'company',
#   'character',
#   'None',
#   'None',
#   'ferry',
#   'title',
#   'size',
#   'anniversary',
#   'artist',
#   'None',
#   'singer',
#   'singer',
#   'woman',
#   'None',
#   'sea',
#   'country',
#   'None',
#   'None',
#   'None',
#   'constellation',
#   'river',
#   'name',
#   'island',
#   'dancer',
#   'character',
#   'movie',
#   'None',
#   'None',
#   'spirit',
#   'None',
#   'company',
#   'None',
#   'building',
#   'sitcom',
#   'None',
#   'detective',
#   'bowler',
#   'None',
#   'None',
#   'None',
#   'None',
#   'explorer',
#   'Song',
#   'series',
#   'None',
#   'resident',
#   'currency',
#   'None',
#   'country',
#   'country',
#   'city',
#   'None',
#   'character',
#   'year',
#   'November',
#   'Bug',
#   'laboratory',
#   'helicopter',
#   'consort',
#   'capital',
#   'girls',
#   'None',
#   'area',
#   'None',
#   'None',
#   'None',
#   'Numerals',
#   'None',
#   'statesman',
#   'Box',
#   'bird',
#   'capital',
#   'None',
#   'plays',
#   'Emperor',
#   'None',
#   'character',
#   'None',
#   'favourite',
#   'None',
#   'None',
#   'age',
#   'None',
#   'sci',
#   'gulf',
#   'None',
#   'War',
#   'capital',
#   'II',
#   'score',
#   'plaque',
#   'singer',
#   'None',
#   'None',
#   'comedy',
#   'series',
#   'saxophonist',
#   'song',
#   'None',
#   'creature',
#   'method',
#   'None',
#   'None',
#   'dish',
#   'Lewis',
#   'None',
#   'city',
#   'None',
#   'actor',
#   'None',
#   'play',
#   'fighter',
#   'album',
#   'series',
#   'discipline',
#   'animal',
#   'minister',
#   'None',
#   'song',
#   'None',
#   'version',
#   'metal',
#   'artist',
#   'creature',
#   'film',
#   'nightclub',
#   'None',
#   'film',
#   'borough',
#   'airline',
#   'company',
#   'None',
#   'country',
#   'creatures',
#   'capital',
#   'vegetable',
#   'None',
#   'fruit',
#   'island',
#   'city',
#   'country',
#   'None',
#   'None',
#   'instrument',
#   'country',
#   'nymph',
#   'ocean',
#   'country',
#   'works',
#   'King',
#   'Dean',
#   'author',
#   'country',
#   'saint',
#   'sport',
#   'None',
#   'group',
#   'Minister',
#   'play',
#   'fluid',
#   'singer',
#   'country',
#   'range',
#   'leader',
#   'actress',
#   'language',
#   'locomotive',
#   'creature',
#   'country',
#   'ion',
#   'part',
#   'liner',
#   'film',
#   'creature',
#   'actor',
#   'animal',
#   'None',
#   'artist',
#   'None',
#   'None',
#   'None',
#   'city',
#   'hook',
#   'singer',
#   'country',
#   'country',
#   'politician',
#   'player',
#   'jewellers',
#   'island',
#   'festival',
#   'company',
#   'park',
#   'year',
#   'None',
#   'animal',
#   'substance',
#   'country',
#   'None',
#   'island',
#   'None',
#   'country',
#   'country',
#   'country',
#   'brother',
#   'country',
#   'diseases',
#   'animal',
#   'disease',
#   'word',
#   'home',
#   'part',
#   'US',
#   'game',
#   'label',
#   'None',
#   'None',
#   'colour',
#   'None',
#   'None',
#   'character',
#   'capital',
#   'title',
#   'country',
#   'colour',
#   'car',
#   'country',
#   'player',
#   'country',
#   'racehorse',
#   'sport',
#   'play',
#   'body',
#   'playwright',
#   'Foxx',
#   'country',
#   'year',
#   'None',
#   'leader',
#   'monarch',
#   'author',
#   'singer',
#   'gangster',
#   'novel',
#   'None',
#   'function',
#   'None',
#   'colours',
#   'team',
#   'None',
#   'None',
#   'word',
#   'sport',
#   'car',
#   'opera',
#   'year',
#   'country',
#   'state',
#   'Minister',
#   'god',
#   'part',
#   'city',
#   'None',
#   'creature',
#   'None',
#   'capital',
#   'animal',
#   'country',
#   'crop',
#   'city',
#   'actor',
#   'monarch',
#   'None',
#   'breed',
#   'None',
#   'None',
#   'country',
#   'number',
#   'country',
#   'poet',
#   'country',
#   'None',
#   'monarch',
#   'country',
#   'None',
#   'series',
#   'body',
#   'None',
#   'None',
#   'creatures',
#   'fruit',
#   'county',
#   'item',
#   'colour',
#   'city',
#   'ingredient',
#   'None',
#   'actor',
#   'fish',
#   'None',
#   'colour',
#   'butter',
#   'None',
#   'country',
#   'film',
#   'city',
#   'None',
#   'countries',
#   'country',
#   'None',
#   'rank',
#   'animal',
#   'country',
#   'planet',
#   'opera',
#   'film',
#   'None',
#   'game',
#   'franchise',
#   'None',
#   'None',
#   'None',
#   'Mark',
#   'angles',
#   'delicacy',
#   'None',
#   'part',
#   'country',
#   'swimmer',
#   'word',
#   'author',
#   'title',
#   'Guetta',
#   'None',
#   'triangle',
#   'element',
#   'dish',
#   'None',
#   'bone',
#   'city',
#   'comic',
#   'II',
#   'state',
#   'None',
#   'None',
#   'child',
#   'newspaper',
#   'country',
#   'wife',
#   'character',
#   'None',
#   'country',
#   'King',
#   'None',
#   'country',
#   'figure',
#   'athlete',
#   'street',
#   'country',
#   'language',
#   'None',
#   'None',
#   'Series',
#   'country',
#   'show',
#   'President',
#   'tissue',
#   'part',
#   'country',
#   'Registration',
#   'country',
#   'country',
#   'country',
#   'singer',
#   'None',
#   'foodstuff',
#   'series',
#   'item',
#   'None',
#   'Gilbert',
#   'religion',
#   'country',
#   'colour',
#   'part',
#   'None',
#   'relation',
#   'leaves',
#   'druid',
#   'county',
#   'None',
#   'None',
#   'athletes',
#   'US',
#   'nation',
#   'part',
#   'None',
#   'cathedral',
#   'None',
#   'country',
#   'letter',
#   'concert',
#   'None',
#   'country',
#   'capital',
#   'None',
#   'country',
#   'element',
#   'None',
#   'flower',
#   'None',
#   'US',
#   'instructors',
#   'father',
#   'Rubens',
#   'insects',
#   'None',
#   'play',
#   'mammals',
#   'city',
#   'actress',
#   'None',
#   'None',
#   'dish',
#   'country',
#   'Torches',
#   'None',
#   'film',
#   'sport',
#   'camel',
#   'part',
#   'novel',
#   'None',
#   'charity',
#   'player',
#   'volcano',
#   'US',
#   'country',
#   'country',
#   'country',
#   'None',
#   'actor',
#   'None',
#   'country',
#   'month',
#   'month',
#   'None',
#   'title',
#   'None',
#   'None',
#   'shrub',
#   'city',
#   'team',
#   'None',
#   'state',
#   'waterfall',
#   'number',
#   'creature',
#   'Hemingway',
#   'painter',
#   'art',
#   'event',
#   'killer',
#   'singer',
#   'None',
#   'None',
#   'capital',
#   'river',
#   'language',
#   'film',
#   'line',
#   'film',
#   'borough',
#   'gerbil',
#   'dragon',
#   'group',
#   'bird',
#   'lead',
#   'system',
#   'None',
#   'country',
#   'term',
#   'island',
#   'country',
#   'sister',
#   'stage',
#   'None',
#   'hobby',
#   'drink',
#   'plant',
#   'title',
#   'church',
#   'country',
#   'state',
#   'Radio',
#   'river',
#   'capital',
#   'None',
#   'None',
#   'band',
#   'bell',
#   'country',
#   'None',
#   'plays',
#   'None',
#   'bridge',
#   'sport',
#   'country',
#   'song',
#   'None',
#   'film',
#   'year',
#   'pigment',
#   'year',
#   'newspaper',
#   'jumper',
#   'show',
#   'game',
#   'composer',
#   'number',
#   'colour',
#   'series',
#   'game',
#   'city',
#   'part',
#   'None',
#   'country',
#   'school',
#   'job',
#   'band',
#   'rhyme',
#   'None',
#   'island',
#   'title',
#   'None',
#   'creature',
#   'creature',
#   'year',
#   'film',
#   'None',
#   'None',
#   'None',
#   'None',
#   'slug',
#   'capital',
#   'creature',
#   'countries',
#   'fin',
#   'None',
#   'plant',
#   'None',
#   'month',
#   'None',
#   'None',
#   'city',
#   'country',
#   'company',
#   'None',
#   'philosopher',
#   'sport',
#   'drink',
#   'band',
#   'group',
#   'title',
#   'club',
#   'country',
#   'None',
#   'number',
#   'country',
#   'religion',
#   'table',
#   'None',
#   'creator',
#   'art',
#   'animal',
#   'country',
#   'None',
#   'river',
#   'side',
#   'None',
#   'None',
#   'wife',
#   'cockerel',
#   'team',
#   'nation',
#   'Lance',
#   ...],
#  'bert_solvable': [False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   ...],
#  'docqa_solvable': [False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   False,
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   False,
#   False,
#   True,
#   ...]}

# %%
def get_at(question):
    wh_word = findWHword(question)
    if wh_word == 'None':
        return 'None'
    elif wh_word == 'what' or wh_word == 'which':
        return detailAnsType(question)[1] #we don't need the detailed ans type
    else:
        return wh_word
assert get_at('Where was Obama born?') == "where"
assert get_at('When was Obama born?') == "when"
assert get_at('In which country was Obama born?') == 'country'
assert get_at('What policy did he follow?') == 'policy'
assert get_at('What to do in Seoul') == 'None'

# %%
def increment_frequency(d, k):
    if k in d:
        d[k] = d[k]+1
    else:
        d[k] = 1

# %%
dict_freq_lat = {}

for instance in tqdm_notebook(train['Data']):
    question = clearquestion(instance['Question'])
    at = get_at(question)
    increment_frequency(dict_freq_lat, at)
# Out:
# HBox(children=(IntProgress(value=0, max=61888), HTML(value='')))

# %%
df

df_filter = df.loc[(df['whtype'] == 'what') | (df['whtype'] == 'which')]

df_bert = df_filter[['qid','lattype','bert_solvable']]
df_docqa = df_filter[['qid','lattype','docqa_solvable']]

count_bert = df_bert.groupby(['lattype','bert_solvable']).count()
count_docqa = df_docqa.groupby(['lattype','docqa_solvable']).count()


count_bert = count_bert.unstack(level=1)
count_bert.columns = count_bert.columns.droplevel(level=0)
print (count_bert)

count_docqa = count_docqa.unstack(level=1)
count_docqa.columns = count_docqa.columns.droplevel(level=0)
print (count_docqa)


count_bert = count_bert.fillna(0)
count_bert['Total'] = count_bert.sum(axis=1)

count_docqa = count_docqa.fillna(0)
count_docqa['Total'] = count_docqa.sum(axis=1)

result_bert = count_bert
result_docqa = count_docqa

result_bert['ratio'] = result_bert[True]/result_bert['Total']
result_docqa['ratio'] = result_docqa[True]/result_docqa['Total']

average_correct_rate = dict()
dot = []
for lat in result_bert.index:
    summa = (result_bert.loc[lat, 'ratio'] + result_docqa.loc[lat, 'ratio'])
    avg = summa*1.0/2
    
    if lat in dict_freq_lat:
        dot.append((dict_freq_lat[lat], avg))
# Out:
# bert_solvable  False  True
# lattype
# .                1.0    NaN
# /songwriter      NaN    1.0
# 1970s            NaN    1.0
# A                NaN    1.0
# Act              NaN    1.0
# ...              ...    ...
# years            1.0    NaN
# yogurt           NaN    1.0
# youth            NaN    1.0
# ’                NaN    3.0
# “                1.0    NaN
#
# [1558 rows x 2 columns]
# docqa_solvable  False  True
# lattype
# .                 1.0    NaN
# /songwriter       NaN    1.0
# 1970s             NaN    1.0
# A                 NaN    1.0
# Act               NaN    1.0
# ...               ...    ...
# years             1.0    NaN
# yogurt            NaN    1.0
# youth             NaN    1.0
# ’                 1.0    2.0
# “                 NaN    1.0
#
# [1558 rows x 2 columns]

# %%
import matplotlib

fig = plt.figure(1)
ax = fig.add_subplot(111, facecolor='white')

x,y = zip(*dot)
plt.scatter(x, y, color='black', alpha= 0.5)
plt.xlim(-50, 750)
np.corrcoef(x, y)
#ax.set_facecolor("w")
matplotlib.pyplot.ylabel('correct rate per lat in dev set')
matplotlib.pyplot.xlabel('# of queries per lat in training set')
plt.title('Correlation between the Number of Dataset and Accuracy in LAT Anaylsis_triviaQA')
# Out:
# Text(0.5, 1.0, 'Correlation between the Number of Dataset and Accuracy in LAT Anaylsis_triviaQA')

# %%
import numpy as np
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.04064191],
#        [0.04064191, 1.        ]])

# %%
pd.DataFrame(rand(10, 4))
# Out:
#           0         1         2         3
# 0  0.070429  0.314044  0.198377  0.046965
# 1  0.749975  0.313324  0.588196  0.009443
# 2  0.048844  0.023699  0.762604  0.092510
# 3  0.564028  0.023477  0.137801  0.141642
# 4  0.378162  0.212360  0.256653  0.705599
# 5  0.041651  0.066077  0.120181  0.473346
# 6  0.256582  0.133719  0.114964  0.538792
# 7  0.220245  0.159481  0.318749  0.242615
# 8  0.503184  0.947943  0.611468  0.419353
# 9  0.440137  0.689202  0.118517  0.299765

# %%
PosTagger("a,b,c,d or e is alphabet")
# Out:
# [('a', 'DT'),
#  (',', ','),
#  ('b', 'NN'),
#  (',', ','),
#  ('c', 'NN'),
#  (',', ','),
#  ('d', 'NN'),
#  ('or', 'CC'),
#  ('e', 'NN'),
#  ('is', 'VBZ'),
#  ('alphabet', 'JJ')]

# %% [markdown]
# ## NN list check

# %%
entity_list_qid = []
for instance in tqdm_notebook(dev):
    
    question = clearquestion(instance['Question'])
    pos_list = PosTagger(question)
    
    posstr = ""
    for word, pos in pos_list:
        posstr += pos
    
    if ('NNCCNN' in posstr) or ('NN,NN' in posstr): 
        entity_list_qid.append(instance['QuestionId'])
# Out:
# HBox(children=(IntProgress(value=0, max=7993), HTML(value='')))

# %%
len(set(entity_list_qid) & rc_wrong) / len(set(entity_list_qid))
# Out:
# 0.5345345345345346

# %%
 len(set(entity_list_qid))
# Out:
# 333
